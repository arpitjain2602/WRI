# %%
from preprocess.arpit_v2 import *
from preprocess.preprocess_v2 import *
from preprocess.preprocess_v2 import preprocess
import os
import inspect
import time
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pickle
from models.LDA_multi_level import lda_model_multi_level
from models.LDA_single_level import lda_model_single_level
from newsplease import NewsPlease
print('------------------------------------------------------')
print('- Imports Done')
# Out:
# ------------------------------------------------------
# - Imports Done

# %% [markdown]
# ## LDA on gold_standard.csv - Text

# %% [markdown]
# ### Extracting texts

# %%
# One way to get articles corresponding to gold-standards are

def load_obj(month, idx):
    month = str(month).zfill(2)
    idx = str(idx).zfill(5)
    with open("data/texts/{}/{}.pkl".format(month, idx), "rb") as f:
        return pickle.load(f)
    
def load_dict(month):
    month = str(month).zfill(2)
    with open("data/metadata/matching/{}.pkl".format(month), "rb") as f:
        return pickle.load(f)
    
gs = pd.read_csv('data/gold-standard/gold_standard.csv')

gs_articles = {}

for i in range(len(gs)):
    article = load_obj(gs['month'][i], gs['ids'][i])
    gs_articles[i] = article

# %%
print('Total articles: ' ,len(gs_articles))
# Out:
# Total articles:  208

# %%
gs_text = []
for key, value in gs_articles.items():
    gs_text.append(value.text)
gs_text = np.array(gs_text)

# %%
raw_docs = gs_text

# %%
type(raw_docs)
# Out:
# numpy.ndarray

# %%
# DATA
# Note that raw docs is a numpy array. 
# Example element is: 
# 'Logical Disk Free Space is low, Description: The disk C: on computer sjcphxstg02.strykercorp.com is running out of disk space. The values that exceeded the thre'
# data_file_string = 'short_description.pkl'

# data_file_string = 'gold_standard.csv'
# data_file = os.path.join(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))),'data',data_file_string)
# raw_docs = pickle.load(open(data_file,'rb'))

print('- Imported Data')
# Out:
# - Imported Data

# %%
# PRE-PROCESSING
preprocess_steps_and_order = {
	'make_lowercase': [True],
	'punctuation_removal':[True],
	'whitespace_removal': [True],
	'store_alphanumeric': [False],
	'pos_removal_nltk': [True, {'pos_removal_nltk_list':['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ',  'PRP','PRP$',  'RB','RBR','RBS','RP',  'JJ','JJR','JJS',   'CC','DT','EX','IN',   'WDT','WP','WP$','WRB']}],
	'tokenization_nltk': [False],
	'lemmatization_tokenization_spacy': [True],
	'stopwords_removal_nltk': [True],
	'stopwords_removal_spacy': [False],
	'make_bigrams_gensim':[True, {'make_bigrams_gensim': True, 'bigrams_min_count': 10, 'bigrams_threshold': 10}],
	'make_trigrams_gensim':[True, {'make_trigrams_gensim': True, 'trigrams_min_count': 10, 'trigrams_threshold': 10}],
	'min_max_length_removal':[False, {'min_max_length_removal': False, 'mmlr_min_len': 3, 'mmlr_max_len': 50, 'mmlr_deacc': False}]
	}

preprocess_functions = {
	'make_lowercase': make_lowercase,
	'punctuation_removal': punctuation_removal,
	'whitespace_removal': whitespace_removal,
	'store_alphanumeric': store_alphanumeric,
	'pos_removal_nltk': pos_removal_nltk,
	'tokenization_nltk': tokenization_nltk,
	'lemmatization_tokenization_spacy': lemmatization_tokenization_spacy,
	'stopwords_removal_nltk': stopwords_removal_nltk,
	'stopwords_removal_spacy': stopwords_removal_spacy,
	'make_bigrams_gensim': make_bigrams_gensim,
	'make_trigrams_gensim': make_trigrams_gensim,
	'min_max_length_removal': min_max_length_removal
	}

# %%
# MODELS
models_dict = {
	'LDA_single_level': lda_model_single_level,
	'LDA_multi_level': lda_model_multi_level,
}

# %%
# SPECIFICATIONS
specifications = {
	# 'model':'LDA_single_level', # Can be LDA_multi_level
	'level':2,
	'num_topics_list_level_1':[5,10,15,20,25,30,35,40],
	'num_topics_list_level_2':[3,5,8,11],
	'num_topics_list_level_3':[1,2,3,4,5],
	'coherence':'c_v',
	'need_best_topic': True,
	'model_selection_metric':'coherence', # or 'perplexity',
	'debug':True,
    'sample_to_print':1,
#     'pos_removal_spacy_list':['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE'],
}

# %%
print('*****************************************************')
print('- Starting preprocessing')
dictionary, corpus, doc_list = preprocess(
								raw_docs = raw_docs, 
								preprocess_functions = preprocess_functions, 
								preprocess_steps_and_order = preprocess_steps_and_order, 
								debug=specifications['debug'])
# Out:
# *****************************************************
# - Starting preprocessing
# --
# data_sample out of  208
# ['6.15 am: Hardoi: Shelter home where only 2 out registered 21 women were found during an inspection on June 7 was sealed and manager Arti Agarwal was arrested yesterday. It was found that fake names were registered in the shelter home to gain donations from the administration.'
#  'Recent rains in Kerala and the Malnad region of Karnataka have left a trail a destruction in India’s major spice-growing regions.\nCoupled with landslips, the rains have adversely affected plantation crops such as ginger, black pepper, cardamom coffee, nutmeg, rubber and tea. Though government agencies are yet to ascertain the quantum of loss in the plantation sector, farming sources said that the loss incurred by the sector is about ₹2,100 crore in Karnataka and ₹800 crore in Kerala.\nFarmers cultivating short term crop such as ginger were relieved when they received good pre-monsoon showers in April. But ginger farms in Kerala and Karnataka submerging in floods starting June has dampened their hopes. Ginger rhizomes have since been affected by the soft rot disease. Heavy rains in ginger growing regions of Mysuru, Coorg, Chikkamagaluru, Hassan and Shimoga districts in Karnataka and Wayanad, Palakkad, Pathanamthitta and Idukki districts in Kerala in June flooded the fields.\n“I have spent nearly ₹50 lakh to cultivate ginger on 10 acres of leased land but I am not sure if I can recoup even a quarter of the expense,” said Manjunath, a farmer at Kushalnagar in Coorg.\nThe rains wiped out ginger rhizomes on almost 5,000 hectares in Karnataka and 2,500 hectares in Kerala, Navrang Mohanan, president, South Indian Ginger Growers’ Association told The Hindu.\nImpact on pepper\n“Torrential rains have washed off black pepper vines in many parts of the two States. This will adversely affect pepper production in the coming season,” Kishore Shamji Kuruwa, Cochin Chapter head, Indian Pepper and Spice Traders, Farmers, Producers and Planters Consortium, said.\n“High moisture content owing to [the] rains has triggered fungal diseases like quick wilt and soft wilt.” Pepper production may fall 40-50% next season, he added.\nCardamom plants cultivated on hundreds of acres have been destroyed even as the cardamom season has just begun. K.S. Mathew, president, Vandanmedu Green Gold Cardamom farmer Producer Company in Idukki said there would be a 30%-40% fall in total production this season .\nThe floods have also hit nutmeg, a promising crop gaining popularity in Kerala. Close to 80% of the
# 0.0 % done
#
#        ##### Lemmatization and Tokenization Done using Spacy! Time Taken -  5.759982109069824
# --
# stopwords_removal_nltk data_sample out of  208
# [['6', '15', 'shelter', 'home', '2', '21', 'woman', 'inspection', 'june', '7', 'manager', 'arti', 'agarwal', 'yesterday', 'name', 'shelter', 'home', 'to', 'donation', 'administration'], ['rain', 'kerala', 'region', 'karnataka', 'trail', 'destruction', 'spice', 'region', 'landslip', 'rain', 'plantation', 'crop', 'ginger', 'pepper', 'cardamom', 'coffee', 'rubber', 'tea', 'government', 'agency', 'to', 'quantum', 'loss', 'plantation', 'sector', 'farm', 'source', 'loss', 'sector', '100', 'crore', 'karnataka', '₹800', 'crore', 'kerala', 'farmer', 'term', 'crop', 'ginger', 'pre', 'monsoon', 'shower', 'april', 'ginger', 'farm', 'kerala', 'karnataka', 'submerging', 'flood', 'june', 'hope', 'rhizome', 'rot', 'disease', 'rain', 'ginger', 'region', 'mysuru', 'coorg', 'chikkamagaluru', 'hassan', 'district', 'karnataka', 'wayanad', 'palakkad', 'pathanamthitta', 'district', 'kerala', 'june', 'field', 'lakh', 'to', 'ginger', '10', 'acre', 'land', 'i', 'can', 'quarter', 'expense', '"', 'manjunath', 'farmer', 'kushalnagar', 'coorg', 'rain', 'ginger', 'rhizome', '5', '000', 'hectare', 'karnataka', '2', '500', 'hectare', 'kerala', 'mohanan', 'president', 'ginger', 'grower', '’', 'association', 'impact', 'rain', 'pepper', 'vine', 'part', 'two', 'state', 'will', 'production', 'season', '"', 'kuruwa', 'cochin', 'chapter', 'head', 'pepper', 'spice', 'trader', 'farmer', 'producer', 'planter', 'consortium', 'moisture', 'content', 'to', 'rain', 'disease', 'wilt', 'wilt', 'production', 'may', '40', '50', 'season', 'cardamom', 'plant', 'hundred', 'acre', 'cardamom', 'season', 'mathew', 'president', 'vandanmedu', 'gold', 'cardamom', 'farmer', 'producer', 'company', 'idukki', 'would', '30', '40', 'fall', 'production', 'season', 'flood', 'promise', 'crop', 'popularity', 'kerala', 'to', '80', '22', '070', 'hectare', 'land', 'cultivation', 'coffee', 'board', 'calamity', 'survey', 'to', 'loss', 'coffee', 'sector', 'crop', 'loss', 'damage', 'to', 'plant', 'berry', 'to', 'rot', 'disease', 'to', 'flood', 'm', 'karutha', 'deputy', 'director', 'coffee', 'board', 'extension', 'coffee', 'industry', 'source', 'coffee', 'production', 'to', '30', 'robusta', 'variety', '20', 'country', '2018', '19', 'to', 'flood', 'landslip', 'coffee', 'area', 'production', 'july', 'august', 'to', 'rain', 'region', 'board', 'source'], ['seven', 'assassination', 'convict', 'rajiv', 'gandhi', 'tamil', 'nadu', 'can', 'not', 'government', 'court', 'friday', 'case', 'assassination', 'minister', 'ndtv', 'today', 'bureau', 'investigation', 'cbi', 'india', 'case', 'release', 'seven', 'convict', 'court', 'tamil', 'nadu', 'decision', 'april', '18', 'centre', 'court', 'seven', 'convict', 'jail', '27', 'year', 'court', 'centre', 'to', 'to', 's', 'request', 'to', 'constitution', 'bench', 'supreme', 'court', 'judge', '2015', 'convict', 'government', 'consent', 'convict', 'nalini', 'sriharan', 'jayakumar', 'ravichandran', 'life', 'term', 'gandhi', '1991', 'woman', 'operative', 'ltte', 'rally', 'town', 'bomb', 'to', 'chest', 'april', 'madras', 'court', 's', 'request', 'release', 'death', 'sentence', 'request', 'leader', 'wife', 'rajiv', 'gandhi', 'convict', 'perarivalan', 'case', 'conviction', 'court', 'march', 'perarivalan', 'two', 'nine', 'volt', 'battery', 'belt', 'bomb', '19', 'week', 'assassination', 'court', 'idea', 'battery', '14', 'year', 'confinement', 'to', 'death', 'sentence', 'to', 'life', 'term', 'court', '2014', 'congress', 'president', 'rahul', 'son', 'rajiv', 'gandhi', 'objection', 'to', 'release', 'tamil', 'film', 'director', 'pa', 'ranjith', '2014', 'minister', 'j', 'jayalalithaa', 'to', 'convict', 'centre', 'congress', 'government', 'power', 'decision', 'court', 'state', 'could', 'decision', 'centre', 'sanction', 'case', 'cbi']]
#
#        ##### Stopwords Removed using NLTK! Time Taken -  0.026103973388671875
# --
# data_sample out of  208
# [['shelter', 'woman', 'inspection', 'june', 'manager', 'arti', 'agarwal', 'yesterday', 'name', 'shelter', 'donation', 'administration'], ['rain', 'kerala', 'region', 'karnataka', 'trail', 'destruction', 'spice', 'region', 'landslip', 'rain', 'plantation', 'crop', 'ginger', 'pepper', 'cardamom', 'coffee', 'rubber', 'tea', 'government', 'agency', 'quantum', 'loss', 'plantation', 'sector', 'farm', 'source', 'loss', 'sector', 'crore', 'karnataka', '₹800', 'crore', 'kerala', 'farmer', 'term', 'crop', 'ginger', 'pre', 'monsoon', 'shower', 'april', 'ginger', 'farm', 'kerala', 'karnataka', 'submerging', 'flood', 'june', 'hope', 'rhizome', 'rot', 'disease', 'rain', 'ginger', 'region', 'mysuru', 'coorg', 'chikkamagaluru', 'hassan', 'district', 'karnataka', 'wayanad', 'palakkad', 'pathanamthitta', 'district', 'kerala', 'june', 'field', 'lakh', 'ginger', 'acre', 'land', 'quarter', 'expense', '"', 'manjunath', 'farmer', 'kushalnagar', 'coorg', 'rain', 'ginger', 'rhizome', 'hectare', 'karnataka', 'hectare', 'kerala', 'mohanan', 'president', 'ginger', 'grower', '’', 'association', 'impact', 'rain', 'pepper', 'vine', 'part', 'state', 'production', 'season', '"', 'kuruwa', 'cochin', 'chapter', 'head', 'pepper', 'spice', 'trader', 'farmer', 'producer', 'planter', 'consortium', 'moisture', 'content', 'rain', 'disease', 'wilt', 'wilt', 'production', 'season', 'cardamom', 'plant', 'acre', 'cardamom', 'season', 'mathew', 'president', 'vandanmedu', 'gold', 'cardamom', 'farmer', 'producer', 'company', 'idukki', 'fall', 'production', 'season', 'flood', 'promise', 'crop', 'popularity', 'kerala', 'hectare', 'land', 'cultivation', 'coffee', 'board', 'calamity', 'survey', 'loss', 'coffee', 'sector', 'crop', 'loss', 'damage', 'plant', 'berry', 'rot', 'disease', 'flood', 'karutha', 'deputy', 'director', 'coffee', 'board', 'extension', 'coffee', 'industry', 'source', 'coffee', 'production', 'robusta', 'variety', 'country', 'flood', 'landslip', 'coffee', 'area', 'production', 'july', 'august', 'rain', 'region', 'board', 'source'], ['assassination', 'convict', 'rajiv', 'gandhi', 'tamil', 'nadu', 'government', 'court', 'friday', 'case', 'assassination', 'minister', 'ndtv', 'today', 'bureau', 'investigation', 'cbi', 'india', 'case', 'release', 'convict', 'court', 'tamil', 'nadu', 'decision', 'april', 'centre', 'court', 'convict', 'jail', 'year', 'court', 'centre', 'request', 'constitution', 'bench', 'supreme', 'court', 'judge', 'convict', 'government', 'consent', 'convict', 'nalini', 'sriharan', 'jayakumar', 'ravichandran', 'life', 'term', 'gandhi', 'woman', 'operative', 'ltte', 'rally', 'town', 'bomb', 'chest', 'april', 'madras', 'court', 'request', 'release', 'death', 'sentence', 'request', 'leader', 'wife', 'rajiv', 'gandhi', 'convict', 'perarivalan', 'case', 'conviction', 'court', 'march', 'perarivalan', 'volt', 'battery', 'belt', 'bomb', 'week', 'assassination', 'court', 'idea', 'battery', 'year', 'confinement', 'death', 'sentence', 'life', 'term', 'court', 'congress', 'president', 'rahul', 'son', 'rajiv', 'gandhi', 'objection', 'release', 'tamil', 'film', 'director', 'pa', 'ranjith', 'minister', 'jayalalithaa', 'convict', 'centre', 'congress', 'government', 'power', 'decision', 'court', 'state', 'decision', 'centre', 'sanction', 'case', 'cbi']]
#
#        ##### Bi-Grams made using Gensim! Time Taken -  0.14197516441345215
# --
# data_sample out of  208
# [['shelter', 'woman', 'inspection', 'june', 'manager', 'arti', 'agarwal', 'yesterday', 'name', 'shelter', 'donation', 'administration'], ['rain', 'kerala', 'region', 'karnataka', 'trail', 'destruction', 'spice', 'region', 'landslip', 'rain', 'plantation', 'crop', 'ginger', 'pepper', 'cardamom', 'coffee', 'rubber', 'tea', 'government', 'agency', 'quantum', 'loss', 'plantation', 'sector', 'farm', 'source', 'loss', 'sector', 'crore', 'karnataka', '₹800', 'crore', 'kerala', 'farmer', 'term', 'crop', 'ginger', 'pre', 'monsoon', 'shower', 'april', 'ginger', 'farm', 'kerala', 'karnataka', 'submerging', 'flood', 'june', 'hope', 'rhizome', 'rot', 'disease', 'rain', 'ginger', 'region', 'mysuru', 'coorg', 'chikkamagaluru', 'hassan', 'district', 'karnataka', 'wayanad', 'palakkad', 'pathanamthitta', 'district', 'kerala', 'june', 'field', 'lakh', 'ginger', 'acre', 'land', 'quarter', 'expense', '"', 'manjunath', 'farmer', 'kushalnagar', 'coorg', 'rain', 'ginger', 'rhizome', 'hectare', 'karnataka', 'hectare', 'kerala', 'mohanan', 'president', 'ginger', 'grower', '’', 'association', 'impact', 'rain', 'pepper', 'vine', 'part', 'state', 'production', 'season', '"', 'kuruwa', 'cochin', 'chapter', 'head', 'pepper', 'spice', 'trader', 'farmer', 'producer', 'planter', 'consortium', 'moisture', 'content', 'rain', 'disease', 'wilt', 'wilt', 'production', 'season', 'cardamom', 'plant', 'acre', 'cardamom', 'season', 'mathew', 'president', 'vandanmedu', 'gold', 'cardamom', 'farmer', 'producer', 'company', 'idukki', 'fall', 'production', 'season', 'flood', 'promise', 'crop', 'popularity', 'kerala', 'hectare', 'land', 'cultivation', 'coffee', 'board', 'calamity', 'survey', 'loss', 'coffee', 'sector', 'crop', 'loss', 'damage', 'plant', 'berry', 'rot', 'disease', 'flood', 'karutha', 'deputy', 'director', 'coffee', 'board', 'extension', 'coffee', 'industry', 'source', 'coffee', 'production', 'robusta', 'variety', 'country', 'flood', 'landslip', 'coffee', 'area', 'production', 'july', 'august', 'rain', 'region', 'board', 'source'], ['assassination', 'convict', 'rajiv', 'gandhi', 'tamil_nadu', 'government', 'court', 'friday', 'case', 'assassination', 'minister', 'ndtv', 'today', 'bureau', 'investigation', 'cbi', 'india', 'case', 'release', 'convict', 'court', 'tamil_nadu', 'decision', 'april', 'centre', 'court', 'convict', 'jail', 'year', 'court', 'centre', 'request', 'constitution', 'bench', 'supreme', 'court', 'judge', 'convict', 'government', 'consent', 'convict', 'nalini', 'sriharan', 'jayakumar', 'ravichandran', 'life', 'term', 'gandhi', 'woman', 'operative', 'ltte', 'rally', 'town', 'bomb', 'chest', 'april', 'madras', 'court', 'request', 'release', 'death', 'sentence', 'request', 'leader', 'wife', 'rajiv', 'gandhi', 'convict', 'perarivalan', 'case', 'conviction', 'court', 'march', 'perarivalan', 'volt', 'battery', 'belt', 'bomb', 'week', 'assassination', 'court', 'idea', 'battery', 'year', 'confinement', 'death', 'sentence', 'life', 'term', 'court', 'congress_president', 'rahul', 'son', 'rajiv', 'gandhi', 'objection', 'release', 'tamil', 'film', 'director', 'pa', 'ranjith', 'minister', 'jayalalithaa', 'convict', 'centre', 'congress', 'government', 'power', 'decision', 'court', 'state', 'decision', 'centre', 'sanction', 'case', 'cbi']]
#        ##### Tri-Grams made using Gensim! Time Taken -  0.1571059226989746
# ~~~ pre-processing done in  9.728078126907349
#
# - Creating dictionary and corpus

# %%
print('*****************************************************')
print('- Starting model training')
lda_dict = lda_model_single_level(
					dictionary = dictionary,
					corpus = corpus,
					doc_list = doc_list,
					num_topics_list_level_1 = specifications['num_topics_list_level_1'], 
					coherence = specifications['coherence'],
					debug = specifications['debug'],
					need_best_topic = specifications['need_best_topic'],
					model_selection_metric = specifications['model_selection_metric']
					)
# Out:
# *****************************************************
# - Starting model training
#
# Sample data point:  ['shelter', 'woman', 'inspection', 'june', 'manager', 'arti', 'agarwal', 'yesterday', 'name', 'shelter', 'donation', 'administration']
#
# 	### Running LDA for number of topic - 5
# 	LDA Done for 5 topic! Time Taken is 1.8078358173370361
# 	Evaluating model for number of topic - 5
# Coherence - 0.3474074434689314, Perplexity - -7.994466043093748
# ---
# 	### Running LDA for number of topic - 10
# 	LDA Done for 10 topic! Time Taken is 1.5824739933013916
# 	Evaluating model for number of topic - 10
# Coherence - 0.46112388375036006, Perplexity - -8.112409870481969
# ---
# 	### Running LDA for number of topic - 15
# 	LDA Done for 15 topic! Time Taken is 1.6985406875610352
# 	Evaluating model for number of topic - 15
# Coherence - 0.40834543502461085, Perplexity - -9.683901367367854
# ---
# 	### Running LDA for number of topic - 20
# 	LDA Done for 20 topic! Time Taken is 1.8599929809570312
# 	Evaluating model for number of topic - 20
# Coherence - 0.4282078304918617, Perplexity - -10.714467875081803
# ---
# 	### Running LDA for number of topic - 25
# 	LDA Done for 25 topic! Time Taken is 2.168416976928711
# 	Evaluating model for number of topic - 25
# Coherence - 0.3694878975091745, Perplexity - -11.563745446743503
# ---
# 	### Running LDA for number of topic - 30
# 	LDA Done for 30 topic! Time Taken is 2.602344274520874
# 	Evaluating model for number of topic - 30
# Coherence - 0.42684565964922394, Perplexity - -12.354310281241622
# ---
# 	### Running LDA for number of topic - 35
# 	LDA Done for 35 topic! Time Taken is 3.4135019779205322
# 	Evaluating model for number of topic - 35
# Coherence - 0.4181195372858157, Perplexity - -13.118331413559364
# ---
# 	### Running LDA for number of topic - 40
# 	LDA Done for 40 topic! Time Taken is 3.365111827850342
# 	Evaluating model for number of topic - 40
# Coherence - 0.4420002140530297, Perplexity - -14.00804214358015
# ---
# - Done training model on all topics in 47.11111116409302 sec!
# Done Single-Level LDA

# %%
pyLDAvis.enable_notebook()
print(lda_dict['best_topic'])
print(lda_dict['coherence_score'])
print(lda_dict['perplexity_score'])
visualization = pyLDAvis.gensim.prepare(lda_dict['best_lda_model'], lda_dict['corpus'], lda_dict['dictionary'])
# pyLDAvis.save_html(visualization, 'lda_10.html')
visualization
# Out:
# 10
# 0.46112388375036006
# -8.112409870481969
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.060711 -0.035885       1        1  27.018532
# 5      0.099187  0.241657       2        1  19.335304
# 9     -0.067301 -0.040802       3        1  10.730453
# 2     -0.037699 -0.039577       4        1   9.433907
# 4      0.301049 -0.080417       5        1   8.159330
# 6     -0.098386 -0.057429       6        1   6.960221
# 3     -0.066655  0.195998       7        1   6.499334
# 8      0.080769 -0.089995       8        1   5.858151
# 0     -0.100205 -0.076253       9        1   4.499283
# 7     -0.050048 -0.017295      10        1   1.505490, topic_info=     Category        Freq              Term       Total  loglift  logprob
# 3508  Default  109.000000              pump  109.000000  30.0000  30.0000
# 423   Default   75.000000  rescue_operation   75.000000  29.0000  29.0000
# 2160  Default   69.000000              coal   69.000000  28.0000  28.0000
# 674   Default  112.000000       acquisition  112.000000  27.0000  27.0000
# 210   Default   71.000000               cow   71.000000  26.0000  26.0000
# ...       ...         ...               ...         ...      ...      ...
# 68    Topic10    0.768192             plant    5.209221   2.2819  -6.0296
# 2710  Topic10    0.817237              rest    7.696626   1.9534  -5.9677
# 2105  Topic10    0.719271       possibility    5.508198   2.1603  -6.0954
# 900   Topic10    0.771444          research   17.130310   1.0957  -6.0254
# 2411  Topic10    0.716103              fire   26.626427   0.5802  -6.0998
#
# [514 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 1499      1  0.233793    -PRON-
# 1499      3  0.311724    -PRON-
# 1499      5  0.311724    -PRON-
# 1499      6  0.116896    -PRON-
# 4694      9  0.870304     aasra
# ...     ...       ...       ...
# 2922      6  0.800899  yogendra
# 930       1  0.386727         –
# 930       3  0.618763         –
# 4695      9  0.870304       ₹11
# 3159      9  0.931709       ₹21
#
# [824 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 6, 10, 3, 5, 7, 4, 9, 1, 8])

# %%
def get_topics(lda_model):
	topics = lda_model.print_topics()
	print("~~~ Topics are:")
	for i in range(len(topics)):
		print('Topic ',i)
		print(topics[i][1])
		print(' ')

# %%
get_topics(lda_dict['best_lda_model'])
# Out:
# ~~~ Topics are:
# Topic  0
# 0.050*"mine" + 0.042*"encroachment" + 0.041*"meghalaya" + 0.040*"resident" + 0.039*"miner" + 0.039*"tragedy" + 0.039*"diver" + 0.038*"debt" + 0.037*"effort" + 0.037*"airlift"
#
# Topic  1
# 0.082*"land" + 0.074*"acquisition" + 0.073*"government" + 0.067*"court" + 0.022*"march" + 0.016*"cm" + 0.013*"protest" + 0.012*"gujarat" + 0.010*"tamil" + 0.010*"demand"
#
# Topic  2
# 0.099*"india" + 0.045*"coal" + 0.043*"miner" + 0.041*"leopard" + 0.040*"body" + 0.040*"highway" + 0.039*"monk" + 0.037*"forest" + 0.037*"effort" + 0.037*"serviceman"
#
# Topic  3
# 0.030*"crisis" + 0.019*"water" + 0.017*"dam" + 0.015*"govt" + 0.014*"cauvery" + 0.013*"protest" + 0.012*"farm" + 0.010*"aiadmk" + 0.010*"construction" + 0.009*"session"
#
# Topic  4
# 0.062*"violence" + 0.053*"slaughter" + 0.045*"team" + 0.045*"onion" + 0.018*"cow" + 0.015*"day" + 0.015*"bulandshahr" + 0.012*"man" + 0.010*"death" + 0.009*"bjp"
#
# Topic  5
# 0.076*"maharashtra" + 0.073*"issue" + 0.066*"ride" + 0.021*"centre" + 0.011*"project" + 0.011*"river" + 0.009*"capital" + 0.009*"rs" + 0.008*"parliament" + 0.008*"train"

# %%
# print('*****************************************************')
# print('- Starting model training')
# lda_level_1, lda_level_2 = lda_model_multi_level(
# 					level = specifications['level'],
# 					dictionary = dictionary,
# 					corpus = corpus,
# 					doc_list = doc_list,
# 					coherence = specifications['coherence'],
# 					debug = specifications['debug'],
# 					need_best_topic = specifications['need_best_topic'],
# 					model_selection_metric = specifications['model_selection_metric'],
# 					num_topics_list_level_1 = specifications['num_topics_list_level_1'], 
# 					num_topics_list_level_2 = specifications['num_topics_list_level_2'], 
# 					)

# %%
'''
Each bubble on the left-hand side plot represents a topic. 
The larger the bubble, the more prevalent is that topic.

A good topic model will have fairly big, non-overlapping bubbles scattered 
throughout the chart instead of being clustered in one quadrant.

A model with too many topics, will typically have many overlaps, 
small sized bubbles clustered in one region of the chart.

Alright, if you move the cursor over one of the bubbles, the words and bars 
on the right-hand side will update. These words are the salient keywords that form the selected topic.
'''
